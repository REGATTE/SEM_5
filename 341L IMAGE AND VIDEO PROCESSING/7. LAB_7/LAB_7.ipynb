# %%
from skimage import data
import matplotlib.pylab as plt

image = data.camera()

plt.imshow(image,cmap="gray")
plt.imsave('camera.jpg', image)
plt.show()

# %%
max_pix = image.max()
inverse = max_pix - image

# %%
plt.imshow(inverse,cmap="gray")
plt.show()

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt 
   
image = cv2.imread('camera.jpg') 
   
c = 255 / np.log(1 + np.max(image)) 
log_image = c * (np.log(image + 1)) 
   
log_image = np.array(log_image, dtype = np.uint8) 
   
plt.imshow(image,cmap="gray") 
plt.show() 
plt.imshow(log_image,cmap="gray") 
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in log
