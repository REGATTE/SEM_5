# %% [markdown]
# # Q1

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("/Users/regatte/Downloads/IMG_0819.jpg")
plt.figure()
plt.imshow(img)
rgb_weights = [0.2989, 0.5870, 0.1140]
grayscale_image = np.dot(img[...,:3], rgb_weights)
plt.figure()
plt.imshow(grayscale_image, cmap=plt.get_cmap("gray"))

# %% [markdown]
# # Q3

# %%
conda install -c conda-forge opencv
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: \

# %%
import cv2
img = cv2.imread(r'/Users/regatte/Downloads/IMG_0819.jpg')
cv2.imshow('original image',img)
HSV_img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
cv2.imshow('HSV format image',HSV_img)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-55da9f9e2c6d> in <module>
# ----> 1 import cv2
#       2 img = cv2.imread(r'/Users/regatte/Downloads/IMG_0819.jpg')
#       3 cv2.imshow('original image',img)
#       4 HSV_img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
#       5 cv2.imshow('HSV format image',HSV_img)
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# # Q4

# %%
img = cv2.imread('/Users/regatte/Downloads/IMG_0819.jpg')

# %% [markdown]
# BILINEAR INTERPOLATION

# %%
bilinear_img = cv2.resize(img,None, fx = 10, fy = 10, interpolation = cv2.INTER_LINEAR)
bilinear_img

# %% [markdown]
# BICUBIC INTERPOLATION

# %%
img_resized = cv2.resize(img, fx=scale_y, fy=scale_y, interpolation=cv2.INTER_CUBIC)
img_resized

# %% [markdown]
# NEAREST NEIGHBOUR

# %%
near_img = cv2.resize(img,None, fx = 10, fy = 10, interpolation = cv2.INTER_NEAREST)
near_img

# %% [markdown]
# We can see that the Image sharpness increases in the order of Bilinear -> Bicubic -> Neareast Neighbour

# %% [markdown]
# # Q2

# %%
img1 = mpimg.imread('/Users/regatte/Documents/MY GITHUB/SEM_5/341L IMAGE AND VIDEO PROCESSING/2. LAB_2/plant+bg.png')[:600,:600,:3]
imglayer = mpimg.imread('/Users/regatte/Documents/MY GITHUB/SEM_5/341L IMAGE AND VIDEO PROCESSING/2. LAB_2/bg.png')[:600,:600,:3]
sub,add,mup = img1-imglayer, img1+imglayer, img1*imglayer
imgplot = plt.imshow(sub)
plt.show()
imgplot = plt.imshow(add)
plt.show()
imgplot = plt.imshow(mup)
plt.show()
